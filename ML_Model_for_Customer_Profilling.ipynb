# %% [markdown]
# <a href="https://colab.research.google.com/github/boiBASH/Tolaram_Project/blob/main/ML_Model_for_Customer_Profilling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


# Load and clean data
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
# Updated datetime parsing with dayfirst=True
df['delivered_date'] = pd.to_datetime(df['delivered_date'], errors='coerce', dayfirst=True)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0].sort_values(['Customer_Phone', 'SKU_Code', 'delivered_date'])

# Feature engineering
df['prev_date'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq'] = df.groupby(['Customer_Phone', 'SKU_Code']).cumcount()
df['cum_spend'] = df.groupby(['Customer_Phone', 'SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past'] = df['cum_spend'] / df['cum_freq'].replace(0, 1)
df['cum_qty'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past'] = df['cum_qty'] / df['cum_freq'].replace(0, 1)

# Compute targets
df['next_date'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_date'].shift(-1)
df['next_days'] = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend'] = df.groupby(['Customer_Phone', 'SKU_Code'])['spend'].shift(-1)
df['next_qty'] = df.groupby(['Customer_Phone', 'SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy'] = df['next_days'].notnull().astype(int)

# Encode SKU
le_sku = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le_sku.transform(df['SKU_Code'])

# Define features
features = ['recency_days', 'cum_freq', 'avg_spend_past', 'avg_qty_past', 'sku_enc']

# Train classifier
X_clf = df[features]
y_clf = df['y_buy']
Xc_train, Xc_test, yc_train, yc_test = train_test_split(X_clf, y_clf, test_size=0.2, random_state=42)
clf = RandomForestClassifier(n_estimators=20, random_state=42).fit(Xc_train, yc_train)

# Train regressors on positive instances
df_reg = df[df['y_buy'] == 1].dropna(subset=['next_days', 'next_spend', 'next_qty'])
X_reg = df_reg[features]
y_days = df_reg['next_days']
y_spend = df_reg['next_spend']
y_qty = df_reg['next_qty']

reg_days = RandomForestRegressor(n_estimators=20, random_state=42).fit(X_reg, y_days)
reg_spend = RandomForestRegressor(n_estimators=20, random_state=42).fit(X_reg, y_spend)
reg_qty = RandomForestRegressor(n_estimators=20, random_state=42).fit(X_reg, y_qty)

# Predict on latest snapshot
latest = df.groupby(['Customer_Phone', 'SKU_Code']).last().reset_index()
latest['last_purchase_date'] = latest['delivered_date']
latest['recency_days'] = (pd.Timestamp.now() - latest['delivered_date']).dt.days
latest['sku_enc'] = le_sku.transform(latest['SKU_Code'])
latest['cum_freq'] = latest['cum_freq']
latest['avg_spend_past'] = latest['avg_spend_past']
latest['avg_qty_past'] = latest['avg_qty_past']

X_pred = latest[features]
latest['probability'] = clf.predict_proba(X_pred)[:, 1]
latest['pred_days'] = reg_days.predict(X_pred)
latest['pred_next_date'] = latest['last_purchase_date'] + pd.to_timedelta(latest['pred_days'], unit='D')
latest['pred_spend'] = reg_spend.predict(X_pred)
latest['pred_qty'] = reg_qty.predict(X_pred)

# Extract top-3 SKUs per customer based on true probabilities
results = (latest.sort_values(['Customer_Phone', 'probability'], ascending=[True, False])
                  .groupby('Customer_Phone').head(3).reset_index(drop=True))

# Display interactive results
pred_df = results[['Customer_Phone', 'SKU_Code', 'last_purchase_date',
                   'pred_next_date', 'pred_spend', 'pred_qty', 'probability']]
pred_df
# Out:
# <ipython-input-17-ea4517c3a0c5>:10: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
#        Customer_Phone  SKU_Code last_purchase_date  \
# 0          7010009941  10002871         2024-11-28
# 1          7010009941  10002849         2024-10-03
# 2          7010009941  10002857         2025-01-02
# 3          7010147753  10002957         2024-11-28
# 4          7010147753  10002835         2024-09-09
# ...               ...       ...                ...
# 11382      9167401267  10003376         2025-01-07
# 11383      9167401267  10002861         2024-10-14
# 11384      9169810564  10000533         2024-11-21
# 11385      9169810564  10002844         2024-12-19
# 11386      9169810564  10002843         2024-12-19
#
#                      pred_next_date     pred_spend  pred_qty  probability
# 0     2024-12-14 14:43:34.718568473   20050.000000  1.023395     0.100000
# 1     2024-10-12 07:12:00.000000000   20607.500000  1.000000     0.000000
# 2     2025-01-23 22:48:00.000000000   24190.000000  1.100000     0.000000
# 3     2024-12-13 16:37:41.149746635  183629.656963  1.617399     0.304423
# 4     2024-10-08 04:18:16.049154156   23242.500000  1.159429     0.251098
# ...                             ...            ...       ...          ...
# 11382 2025-01-31 03:24:24.302564821   19850.000000  1.122391     0.273278
# 11383 2024-10-30 01:06:11.361857771   20000.000000  1.020956     0.173211
# 11384 2024-12-20 14:35:09.733016040   90317.778957  5.902993     0.428003
# 11385 2025-01-09 21:47:19.415802937   24130.000000  1.310417     0.374679
# 11386 2025-01-12 23:26:23.719251333   24130.000000  1.264017     0.359978
#
# [11387 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    roc_auc_score, classification_report,
    mean_absolute_error, mean_squared_error, r2_score
)

# 1) Load & clean
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
df['delivered_date'] = pd.to_datetime(df['delivered_date'], errors='coerce', dayfirst=True)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0] \
       .sort_values(['Customer_Phone','SKU_Code','delivered_date'])

# 2) Features & targets
df['prev_date'] = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq']      = df.groupby(['Customer_Phone','SKU_Code']).cumcount()
df['cum_spend']     = df.groupby(['Customer_Phone','SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past']= df['cum_spend'] / df['cum_freq'].replace(0,1)
df['cum_qty']       = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past']  = df['cum_qty'] / df['cum_freq'].replace(0,1)

df['next_date']  = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(-1)
df['next_days']  = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend']= df.groupby(['Customer_Phone','SKU_Code'])['spend'].shift(-1)
df['next_qty']  = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy']     = df['next_days'].notnull().astype(int)

le_sku = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le_sku.transform(df['SKU_Code'])

features = ['recency_days','cum_freq','avg_spend_past','avg_qty_past','sku_enc']

# 3) Train/test split for classifier
X_clf = df[features]
y_clf = df['y_buy']
Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    X_clf, y_clf, test_size=0.2, random_state=42
)

clf = RandomForestClassifier(n_estimators=20, random_state=42)
clf.fit(Xc_train, yc_train)

# 4) Eval classifier
probs = clf.predict_proba(Xc_test)[:,1]
preds = clf.predict(Xc_test)

print("=== CLASSIFIER METRICS ===")
print("ROC-AUC:", roc_auc_score(yc_test, probs))
print(classification_report(yc_test, preds))

# 5) Prepare train/test for regressors (only positive samples)
df_reg = df[df['y_buy']==1].dropna(subset=['next_days','next_spend','next_qty'])
Xr = df_reg[features]
yd = df_reg['next_days']
ys = df_reg['next_spend']
yq = df_reg['next_qty']

Xr_train, Xr_test, yd_train, yd_test, ys_train, ys_test, yq_train, yq_test = train_test_split(
    Xr, yd, ys, yq, test_size=0.2, random_state=42
)

# 6) Train regressors
reg_days  = RandomForestRegressor(n_estimators=20, random_state=42).fit(Xr_train, yd_train)
reg_spend = RandomForestRegressor(n_estimators=20, random_state=42).fit(Xr_train, ys_train)
reg_qty   = RandomForestRegressor(n_estimators=20, random_state=42).fit(Xr_train, yq_train)

# 7) Eval regressors
print("\n=== REGRESSOR METRICS ===")
for name, y_true, model in [
    ("Next-Days", yd_test, reg_days),
    ("Spend",     ys_test, reg_spend),
    ("Quantity",  yq_test, reg_qty)
]:
    y_pred = model.predict(Xr_test)
    print(f"\n-- {name} --")
    print(" MAE :", mean_absolute_error(y_true, y_pred))
    print(" RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print(" R2  :", r2_score(y_true, y_pred))

# 8) (Optional) Continue with your prediction & top-3 extraction…

pred_df = results[['Customer_Phone', 'SKU_Code', 'last_purchase_date',
                   'pred_next_date', 'pred_spend', 'pred_qty', 'probability']]
pred_df
# Out:
# <ipython-input-21-686416891809>:13: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
# === CLASSIFIER METRICS ===
# ROC-AUC: 0.7606125148882928
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.67      9135
#            1       0.72      0.73      0.72     10649
#
#     accuracy                           0.70     19784
#    macro avg       0.70      0.70      0.70     19784
# weighted avg       0.70      0.70      0.70     19784
#
#
# === REGRESSOR METRICS ===
#
# -- Next-Days --
#  MAE : 17.539359457817106
#  RMSE: 24.46585274359179
#  R2  : 0.060901208560988795
#
# -- Spend --
#  MAE : 34471.54450148744
#  RMSE: 93288.74551944884
#  R2  : 0.13613760968158928
#
# -- Quantity --
#  MAE : 2.4408128650588745
#  RMSE: 6.661168013613155
#  R2  : 0.14571210337317997
#        Customer_Phone  SKU_Code last_purchase_date  \
# 0          7010009941  10002871         2024-11-28
# 1          7010009941  10002849         2024-10-03
# 2          7010009941  10002857         2025-01-02
# 3          7010147753  10002957         2024-11-28
# 4          7010147753  10002835         2024-09-09
# ...               ...       ...                ...
# 11382      9167401267  10003376         2025-01-07
# 11383      9167401267  10002861         2024-10-14
# 11384      9169810564  10000533         2024-11-21
# 11385      9169810564  10002844         2024-12-19
# 11386      9169810564  10002843         2024-12-19
#
#                      pred_next_date     pred_spend  pred_qty  probability
# 0     2024-12-14 14:43:34.718568473   20050.000000  1.023395     0.100000
# 1     2024-10-12 07:12:00.000000000   20607.500000  1.000000     0.000000
# 2     2025-01-23 22:48:00.000000000   24190.000000  1.100000     0.000000
# 3     2024-12-13 16:37:41.149746635  183629.656963  1.617399     0.304423
# 4     2024-10-08 04:18:16.049154156   23242.500000  1.159429     0.251098
# ...                             ...            ...       ...          ...
# 11382 2025-01-31 03:24:24.302564821   19850.000000  1.122391     0.273278
# 11383 2024-10-30 01:06:11.361857771   20000.000000  1.020956     0.173211
# 11384 2024-12-20 14:35:09.733016040   90317.778957  5.902993     0.428003
# 11385 2025-01-09 21:47:19.415802937   24130.000000  1.310417     0.374679
# 11386 2025-01-12 23:26:23.719251333   24130.000000  1.264017     0.359978
#
# [11387 rows x 7 columns]

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.2)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    roc_auc_score, classification_report,
    mean_absolute_error, mean_squared_error, r2_score
)

# 1) Load & clean
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
df['delivered_date'] = pd.to_datetime(
    df['delivered_date'], errors='coerce', dayfirst=True
)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0].sort_values(
    ['Customer_Phone','SKU_Code','delivered_date']
)

# 2) Feature engineering & targets
df['prev_date'] = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq']   = df.groupby(['Customer_Phone','SKU_Code']).cumcount()
df['cum_spend']  = df.groupby(['Customer_Phone','SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past'] = df['cum_spend'] / df['cum_freq'].replace(0,1)
df['cum_qty']    = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past']= df['cum_qty'] / df['cum_freq'].replace(0,1)

df['next_date']   = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(-1)
df['next_days']   = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend']  = df.groupby(['Customer_Phone','SKU_Code'])['spend'].shift(-1)
df['next_qty']    = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy']       = df['next_days'].notnull().astype(int)

le = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le.transform(df['SKU_Code'])

features = ['recency_days','cum_freq','avg_spend_past','avg_qty_past','sku_enc']

# 3) Classifier train/test
Xc = df[features]
yc = df['y_buy']
Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    Xc, yc, test_size=0.2, random_state=42
)

clf = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)
clf.fit(Xc_train, yc_train)

# 4) Classifier eval
probs = clf.predict_proba(Xc_test)[:,1]
preds = clf.predict(Xc_test)
print("ROC-AUC:", roc_auc_score(yc_test, probs))
print(classification_report(yc_test, preds))

# 5) Regressor train/test on positive samples
df_reg = df[df['y_buy']==1].dropna(subset=['next_days','next_spend','next_qty'])
Xr = df_reg[features]
yr_days  = df_reg['next_days']
yr_spend = df_reg['next_spend']
yr_qty   = df_reg['next_qty']

Xr_train, Xr_test, yd_train, yd_test, ys_train, ys_test, yq_train, yq_test = train_test_split(
    Xr, yr_days, yr_spend, yr_qty, test_size=0.2, random_state=42
)

reg_days = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_spend= XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_qty  = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)

reg_days.fit(Xr_train, yd_train)
reg_spend.fit(Xr_train, ys_train)
reg_qty.fit(Xr_train, yq_train)

# 6) Regressor eval
for name, y_true, model in [
    ("Next-Days", yd_test, reg_days),
    ("Spend",     ys_test, reg_spend),
    ("Quantity",  yq_test, reg_qty)
]:
    y_pred = model.predict(Xr_test)
    print(f"\n-- {name} --")
    print(" MAE :", mean_absolute_error(y_true, y_pred))
    print(" RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
    print(" R2  :", r2_score(y_true, y_pred))

# 7) Final top-3 extraction remains the same…

pred_df = results[['Customer_Phone', 'SKU_Code', 'last_purchase_date',
                   'pred_next_date', 'pred_spend', 'pred_qty', 'probability']]
pred_df
# Out:
# <ipython-input-22-3c90999cbc7c>:13: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [16:16:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ROC-AUC: 0.7749623851038586
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68      9135
#            1       0.72      0.76      0.74     10649
#
#     accuracy                           0.71     19784
#    macro avg       0.71      0.71      0.71     19784
# weighted avg       0.71      0.71      0.71     19784
#
#
# -- Next-Days --
#  MAE : 16.67879671712265
#  RMSE: 23.363590977426714
#  R2  : 0.14361361188055288
#
# -- Spend --
#  MAE : 33056.48375879503
#  RMSE: 93532.5650345117
#  R2  : 0.13161612630881137
#
# -- Quantity --
#  MAE : 2.3263789571514644
#  RMSE: 6.8436803690160115
#  R2  : 0.0982567228440826
#        Customer_Phone  SKU_Code last_purchase_date  \
# 0          7010009941  10002871         2024-11-28
# 1          7010009941  10002849         2024-10-03
# 2          7010009941  10002857         2025-01-02
# 3          7010147753  10002957         2024-11-28
# 4          7010147753  10002835         2024-09-09
# ...               ...       ...                ...
# 11382      9167401267  10003376         2025-01-07
# 11383      9167401267  10002861         2024-10-14
# 11384      9169810564  10000533         2024-11-21
# 11385      9169810564  10002844         2024-12-19
# 11386      9169810564  10002843         2024-12-19
#
#                      pred_next_date     pred_spend  pred_qty  probability
# 0     2024-12-14 14:43:34.718568473   20050.000000  1.023395     0.100000
# 1     2024-10-12 07:12:00.000000000   20607.500000  1.000000     0.000000
# 2     2025-01-23 22:48:00.000000000   24190.000000  1.100000     0.000000
# 3     2024-12-13 16:37:41.149746635  183629.656963  1.617399     0.304423
# 4     2024-10-08 04:18:16.049154156   23242.500000  1.159429     0.251098
# ...                             ...            ...       ...          ...
# 11382 2025-01-31 03:24:24.302564821   19850.000000  1.122391     0.273278
# 11383 2024-10-30 01:06:11.361857771   20000.000000  1.020956     0.173211
# 11384 2024-12-20 14:35:09.733016040   90317.778957  5.902993     0.428003
# 11385 2025-01-09 21:47:19.415802937   24130.000000  1.310417     0.374679
# 11386 2025-01-12 23:26:23.719251333   24130.000000  1.264017     0.359978
#
# [11387 rows x 7 columns]

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.11/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.11/dist-packages (from prophet) (0.71)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    roc_auc_score, classification_report,
    mean_absolute_error, mean_squared_error, r2_score
)
from prophet import Prophet
from IPython.display import display

# 3) Load & clean
df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
df = df.rename(columns={
    'Delivered_date': 'delivered_date',
    'Delivered Qty': 'delivered_qty',
    'Redistribution Value': 'spend'
})
df['delivered_date'] = pd.to_datetime(df['delivered_date'], errors='coerce', dayfirst=True)
df['spend'] = df['spend'].str.replace(',', '').astype(float)
df = df[df['delivered_qty'] > 0].sort_values(['Customer_Phone','SKU_Code','delivered_date'])

# 4) Feature engineering & targets
df['prev_date'] = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(1)
df['recency_days'] = (df['delivered_date'] - df['prev_date']).dt.days.fillna(-1)
df['cum_freq']   = df.groupby(['Customer_Phone','SKU_Code']).cumcount()
df['cum_spend']  = df.groupby(['Customer_Phone','SKU_Code'])['spend'].cumsum() - df['spend']
df['avg_spend_past'] = df['cum_spend'] / df['cum_freq'].replace(0,1)
df['cum_qty']    = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].cumsum() - df['delivered_qty']
df['avg_qty_past']= df['cum_qty'] / df['cum_freq'].replace(0,1)

df['next_date']  = df.groupby(['Customer_Phone','SKU_Code'])['delivered_date'].shift(-1)
df['next_days']  = (df['next_date'] - df['delivered_date']).dt.days
df['next_spend'] = df.groupby(['Customer_Phone','SKU_Code'])['spend'].shift(-1)
df['next_qty']   = df.groupby(['Customer_Phone','SKU_Code'])['delivered_qty'].shift(-1)
df['y_buy']      = df['next_days'].notnull().astype(int)

le = LabelEncoder().fit(df['SKU_Code'])
df['sku_enc'] = le.transform(df['SKU_Code'])

features = ['recency_days','cum_freq','avg_spend_past','avg_qty_past','sku_enc']

# 5) Classifier
Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    df[features], df['y_buy'], test_size=0.2, random_state=42
)
clf = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=6, eval_metric='logloss', random_state=42)
clf.fit(Xc_train, yc_train)
probs = clf.predict_proba(Xc_test)[:,1]
preds = clf.predict(Xc_test)
print("=== CLASSIFIER METRICS ===")
print("ROC-AUC:", roc_auc_score(yc_test, probs))
print(classification_report(yc_test, preds))

# 6) Time-series for next purchase date
ts_preds = []
for (cust, sku), grp in df.groupby(['Customer_Phone','SKU_Code']):
    ts = grp[['delivered_date']].rename(columns={'delivered_date':'ds'})
    ts['y'] = 1
    ts = ts.set_index('ds').resample('D').sum().reset_index()
    if len(ts) < 3: continue
    m = Prophet(daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=False)
    m.fit(ts)
    future = m.make_future_dataframe(periods=60)
    fcst = m.predict(future)
    next_day = fcst.loc[fcst['yhat']>0.5,'ds']
    if not next_day.empty:
        ts_preds.append({'Customer_Phone':cust,'SKU_Code':sku,'ts_pred_next_date':next_day.min()})
ts_df = pd.DataFrame(ts_preds)

# 7) Merge TS preds
latest = df.groupby(['Customer_Phone','SKU_Code']).last().reset_index()
latest = latest.merge(ts_df, on=['Customer_Phone','SKU_Code'], how='left')
latest['last_purchase_date'] = latest['delivered_date']

# 8) Regression split with non-null targets
df_reg = df[df['y_buy']==1].dropna(subset=['next_spend','next_qty'])
Xr = df_reg[features]
ys = df_reg['next_spend']
yq = df_reg['next_qty']
Xr_train, Xr_test, ys_train, ys_test, yq_train, yq_test = train_test_split(
    Xr, ys, yq, test_size=0.2, random_state=42
)

reg_spend = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_qty   = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=42)
reg_spend.fit(Xr_train, ys_train)
reg_qty.fit(Xr_train, yq_train)

# 9) Reg metrics
print("=== REGRESSOR METRICS ===")
print("-- Spend -- MAE:", mean_absolute_error(ys_test, reg_spend.predict(Xr_test)),
      "RMSE:", np.sqrt(mean_squared_error(ys_test, reg_spend.predict(Xr_test))),
      "R2:", r2_score(ys_test, reg_spend.predict(Xr_test)))
print("-- Qty   -- MAE:", mean_absolute_error(yq_test, reg_qty.predict(Xr_test)),
      "RMSE:", np.sqrt(mean_squared_error(yq_test, reg_qty.predict(Xr_test))),
      "R2:", r2_score(yq_test, reg_qty.predict(Xr_test)))

# 10) Top-3 extraction
latest['probability']   = clf.predict_proba(latest[features])[:,1]
latest['pred_spend']    = reg_spend.predict(latest[features])
latest['pred_qty']      = reg_qty.predict(latest[features])
latest['pred_next_date']= latest['ts_pred_next_date'].fillna(
    latest['last_purchase_date'] + pd.to_timedelta(latest['next_days'].fillna(0),'D')
)
results = (latest.sort_values(['Customer_Phone','probability'],ascending=[True,False])
            .groupby('Customer_Phone').head(3).reset_index(drop=True))
display(results[['Customer_Phone','SKU_Code','last_purchase_date','pred_next_date','pred_spend','pred_qty','probability']].head(10))
# Out:
# <ipython-input-1-6d8a9ae78391>:15: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Data Analysis - Sample File.csv')
# === CLASSIFIER METRICS ===
# ROC-AUC: 0.7749623851038586
#               precision    recall  f1-score   support
#
#            0       0.70      0.65      0.68      9135
#            1       0.72      0.76      0.74     10649
#
#     accuracy                           0.71     19784
#    macro avg       0.71      0.71      0.71     19784
# weighted avg       0.71      0.71      0.71     19784
# Streaming output truncated to the last 5000 lines.
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/qwmigjij.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/kbxyo7qc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12357', 'data', 'file=/tmp/tmpajsmnivi/qwmigjij.json', 'init=/tmp/tmpajsmnivi/kbxyo7qc.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelp6chau4h/prophet_model-20250505094755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/d1ltls8p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/c8pdr0a7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66315', 'data', 'file=/tmp/tmpajsmnivi/d1ltls8p.json', 'init=/tmp/tmpajsmnivi/c8pdr0a7.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelwscyjffx/prophet_model-20250505094755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/q62aassv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/xgv2d_8y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5277', 'data', 'file=/tmp/tmpajsmnivi/q62aassv.json', 'init=/tmp/tmpajsmnivi/xgv2d_8y.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelh1txvs65/prophet_model-20250505094755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/3ebdxc6p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/1dapogzu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96782', 'data', 'file=/tmp/tmpajsmnivi/3ebdxc6p.json', 'init=/tmp/tmpajsmnivi/1dapogzu.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modellaxjjjjs/prophet_model-20250505094755.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ld801lsu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/f2c7ndir.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56190', 'data', 'file=/tmp/tmpajsmnivi/ld801lsu.json', 'init=/tmp/tmpajsmnivi/f2c7ndir.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelwdgmk27w/prophet_model-20250505094756.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:47:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/066aux97.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/xf_lwg4s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79187', 'data', 'file=/tmp/tmpajsmnivi/066aux97.json', 'init=/tmp/tmpajsmnivi/xf_lwg4s.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelhyscj3ym/prophet_model-20250505094756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/a3orsa74.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/muf01g6j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70261', 'data', 'file=/tmp/tmpajsmnivi/a3orsa74.json', 'init=/tmp/tmpajsmnivi/muf01g6j.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model4thczsiq/prophet_model-20250505094756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/g9_axpij.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/qybqwled.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86605', 'data', 'file=/tmp/tmpajsmnivi/g9_axpij.json', 'init=/tmp/tmpajsmnivi/qybqwled.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelk67rpk95/prophet_model-20250505094756.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 20.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/xedgjhpq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/wkiejyo0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97590', 'data', 'file=/tmp/tmpajsmnivi/xedgjhpq.json', 'init=/tmp/tmpajsmnivi/wkiejyo0.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeluo_ocxgc/prophet_model-20250505094757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/okkn9klp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/4j0kvnmi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88139', 'data', 'file=/tmp/tmpajsmnivi/okkn9klp.json', 'init=/tmp/tmpajsmnivi/4j0kvnmi.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelcilq8phd/prophet_model-20250505094757.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:47:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/r1db4b14.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/upyq7tph.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=49985', 'data', 'file=/tmp/tmpajsmnivi/r1db4b14.json', 'init=/tmp/tmpajsmnivi/upyq7tph.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model7yi1x0vc/prophet_model-20250505094757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/854v00gy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/bhwinxf5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59288', 'data', 'file=/tmp/tmpajsmnivi/854v00gy.json', 'init=/tmp/tmpajsmnivi/bhwinxf5.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelkcrvkugv/prophet_model-20250505094757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/9l_tqobr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/mcdhz4je.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89119', 'data', 'file=/tmp/tmpajsmnivi/9l_tqobr.json', 'init=/tmp/tmpajsmnivi/mcdhz4je.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelch4sdyur/prophet_model-20250505094757.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/dfoi6fk7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/nh7vzhcl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22541', 'data', 'file=/tmp/tmpajsmnivi/dfoi6fk7.json', 'init=/tmp/tmpajsmnivi/nh7vzhcl.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model83jwqyau/prophet_model-20250505094758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/1_j9shpc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7xqv4rsp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46627', 'data', 'file=/tmp/tmpajsmnivi/1_j9shpc.json', 'init=/tmp/tmpajsmnivi/7xqv4rsp.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeltmyd915g/prophet_model-20250505094758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/lf_jneia.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/j_h742yh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83590', 'data', 'file=/tmp/tmpajsmnivi/lf_jneia.json', 'init=/tmp/tmpajsmnivi/j_h742yh.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelt7hglkr9/prophet_model-20250505094758.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/dsm4572a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/pj0twrlk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41636', 'data', 'file=/tmp/tmpajsmnivi/dsm4572a.json', 'init=/tmp/tmpajsmnivi/pj0twrlk.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelyghhixam/prophet_model-20250505094759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/us244gir.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/36r4cjx_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76600', 'data', 'file=/tmp/tmpajsmnivi/us244gir.json', 'init=/tmp/tmpajsmnivi/36r4cjx_.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelu3r1n17z/prophet_model-20250505094759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/_fkox928.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/cel97oyf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16467', 'data', 'file=/tmp/tmpajsmnivi/_fkox928.json', 'init=/tmp/tmpajsmnivi/cel97oyf.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model8le33j7p/prophet_model-20250505094759.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/zc47mx7x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/xduhu5yj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5600', 'data', 'file=/tmp/tmpajsmnivi/zc47mx7x.json', 'init=/tmp/tmpajsmnivi/xduhu5yj.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelvo0ouay3/prophet_model-20250505094759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 10.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/g42l3h5z.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/rc7k8tv0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40672', 'data', 'file=/tmp/tmpajsmnivi/g42l3h5z.json', 'init=/tmp/tmpajsmnivi/rc7k8tv0.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelf5orxjk0/prophet_model-20250505094759.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:47:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:47:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/y7twujjm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/8xt7jymd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37130', 'data', 'file=/tmp/tmpajsmnivi/y7twujjm.json', 'init=/tmp/tmpajsmnivi/8xt7jymd.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model2n75t2vk/prophet_model-20250505094800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/z4wje7xe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/a2pcnaok.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56325', 'data', 'file=/tmp/tmpajsmnivi/z4wje7xe.json', 'init=/tmp/tmpajsmnivi/a2pcnaok.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model3bzik_bc/prophet_model-20250505094800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/dzjhwbfm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/n8ksu37s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82961', 'data', 'file=/tmp/tmpajsmnivi/dzjhwbfm.json', 'init=/tmp/tmpajsmnivi/n8ksu37s.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelih1d8wed/prophet_model-20250505094800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7vt58p5t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/g80koh4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47288', 'data', 'file=/tmp/tmpajsmnivi/7vt58p5t.json', 'init=/tmp/tmpajsmnivi/g80koh4o.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelor1p2z8j/prophet_model-20250505094800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ba4irv1i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ly8afkfp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96301', 'data', 'file=/tmp/tmpajsmnivi/ba4irv1i.json', 'init=/tmp/tmpajsmnivi/ly8afkfp.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelgticyvw2/prophet_model-20250505094800.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/rut1px24.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/a1ub0q_l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68242', 'data', 'file=/tmp/tmpajsmnivi/rut1px24.json', 'init=/tmp/tmpajsmnivi/a1ub0q_l.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelyw0_8tb5/prophet_model-20250505094800.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 4.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/o7bscr9n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/c1vjh00b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26697', 'data', 'file=/tmp/tmpajsmnivi/o7bscr9n.json', 'init=/tmp/tmpajsmnivi/c1vjh00b.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelnyfl73t3/prophet_model-20250505094801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/8zjxh83c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/8yr50aov.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23004', 'data', 'file=/tmp/tmpajsmnivi/8zjxh83c.json', 'init=/tmp/tmpajsmnivi/8yr50aov.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelhj989crt/prophet_model-20250505094801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/cmlp9ap9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/6j4v0jxj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9432', 'data', 'file=/tmp/tmpajsmnivi/cmlp9ap9.json', 'init=/tmp/tmpajsmnivi/6j4v0jxj.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelzbel_9ir/prophet_model-20250505094801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ejjhsfye.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/o91u5x6k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82552', 'data', 'file=/tmp/tmpajsmnivi/ejjhsfye.json', 'init=/tmp/tmpajsmnivi/o91u5x6k.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model7yls6u9_/prophet_model-20250505094801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/awfqa2x2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/au2tiezt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42494', 'data', 'file=/tmp/tmpajsmnivi/awfqa2x2.json', 'init=/tmp/tmpajsmnivi/au2tiezt.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeltxvzkxhq/prophet_model-20250505094801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 18.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/wpr4gjow.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7pkvg0mk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94291', 'data', 'file=/tmp/tmpajsmnivi/wpr4gjow.json', 'init=/tmp/tmpajsmnivi/7pkvg0mk.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model2lpa0g3v/prophet_model-20250505094801.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ob2cqfc_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/isbsd_2i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2535', 'data', 'file=/tmp/tmpajsmnivi/ob2cqfc_.json', 'init=/tmp/tmpajsmnivi/isbsd_2i.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelvy66hf2z/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 12.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/o15cvqbq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/lx4kaem_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38707', 'data', 'file=/tmp/tmpajsmnivi/o15cvqbq.json', 'init=/tmp/tmpajsmnivi/lx4kaem_.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelxotlfh2a/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/buynoh3f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/mr15sbgt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64550', 'data', 'file=/tmp/tmpajsmnivi/buynoh3f.json', 'init=/tmp/tmpajsmnivi/mr15sbgt.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelrcrw293t/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 16.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/6r_2v63q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/zllf26wj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74351', 'data', 'file=/tmp/tmpajsmnivi/6r_2v63q.json', 'init=/tmp/tmpajsmnivi/zllf26wj.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model9dc01yr6/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/_p88zfm_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/pdbipzky.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61791', 'data', 'file=/tmp/tmpajsmnivi/_p88zfm_.json', 'init=/tmp/tmpajsmnivi/pdbipzky.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeltele3fno/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 22.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/la38elmc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/izjlhs3o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16199', 'data', 'file=/tmp/tmpajsmnivi/la38elmc.json', 'init=/tmp/tmpajsmnivi/izjlhs3o.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelf70jq9_g/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/t00dkm3f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/_yc5y0jo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38537', 'data', 'file=/tmp/tmpajsmnivi/t00dkm3f.json', 'init=/tmp/tmpajsmnivi/_yc5y0jo.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modell6554rrk/prophet_model-20250505094802.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/fuulkxvx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/706l5ifi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4196', 'data', 'file=/tmp/tmpajsmnivi/fuulkxvx.json', 'init=/tmp/tmpajsmnivi/706l5ifi.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model13ylrr7_/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/gj4lbkyt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/a091sdw0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93311', 'data', 'file=/tmp/tmpajsmnivi/gj4lbkyt.json', 'init=/tmp/tmpajsmnivi/a091sdw0.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelx2c5uiwa/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/79k1vwtx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/nyv3w5n0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32857', 'data', 'file=/tmp/tmpajsmnivi/79k1vwtx.json', 'init=/tmp/tmpajsmnivi/nyv3w5n0.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeldyaw0g0m/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/1t82b9jv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/4c0cpuqx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31796', 'data', 'file=/tmp/tmpajsmnivi/1t82b9jv.json', 'init=/tmp/tmpajsmnivi/4c0cpuqx.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelm04pqfhc/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/v4fsdk5u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/0kqfk14y.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56283', 'data', 'file=/tmp/tmpajsmnivi/v4fsdk5u.json', 'init=/tmp/tmpajsmnivi/0kqfk14y.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model8bp08jwj/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/t6x10x82.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/16at_1rw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99561', 'data', 'file=/tmp/tmpajsmnivi/t6x10x82.json', 'init=/tmp/tmpajsmnivi/16at_1rw.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model086bld9q/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/53ml5c99.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/v84y0ug2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88219', 'data', 'file=/tmp/tmpajsmnivi/53ml5c99.json', 'init=/tmp/tmpajsmnivi/v84y0ug2.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelsb940wiu/prophet_model-20250505094803.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/8guhrree.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/kz_txkwl.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52956', 'data', 'file=/tmp/tmpajsmnivi/8guhrree.json', 'init=/tmp/tmpajsmnivi/kz_txkwl.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modellp__fv3x/prophet_model-20250505094804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/even0jvi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/acuowtdk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83621', 'data', 'file=/tmp/tmpajsmnivi/even0jvi.json', 'init=/tmp/tmpajsmnivi/acuowtdk.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelnv2jax6h/prophet_model-20250505094804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/8ncxl_fp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/4gyyfmc9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58133', 'data', 'file=/tmp/tmpajsmnivi/8ncxl_fp.json', 'init=/tmp/tmpajsmnivi/4gyyfmc9.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelkw0xwsy8/prophet_model-20250505094804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ynujfm1g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/i0ljfj06.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48527', 'data', 'file=/tmp/tmpajsmnivi/ynujfm1g.json', 'init=/tmp/tmpajsmnivi/i0ljfj06.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelpnfj97k2/prophet_model-20250505094804.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/2ad2o_h1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/3bs4ylsz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92826', 'data', 'file=/tmp/tmpajsmnivi/2ad2o_h1.json', 'init=/tmp/tmpajsmnivi/3bs4ylsz.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelq4key8g2/prophet_model-20250505094804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/nouc5ztl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/461dweks.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42669', 'data', 'file=/tmp/tmpajsmnivi/nouc5ztl.json', 'init=/tmp/tmpajsmnivi/461dweks.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeloei57_a1/prophet_model-20250505094804.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/mnium5ps.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/lkmfpf2e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66895', 'data', 'file=/tmp/tmpajsmnivi/mnium5ps.json', 'init=/tmp/tmpajsmnivi/lkmfpf2e.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelvxqe_kd5/prophet_model-20250505094805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/hxbdko5f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/95y1c6yn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=75323', 'data', 'file=/tmp/tmpajsmnivi/hxbdko5f.json', 'init=/tmp/tmpajsmnivi/95y1c6yn.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model5mlmir2m/prophet_model-20250505094805.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 5.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/yg4g2zef.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7zdzvuje.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64089', 'data', 'file=/tmp/tmpajsmnivi/yg4g2zef.json', 'init=/tmp/tmpajsmnivi/7zdzvuje.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelp7s293vl/prophet_model-20250505094805.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 7.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7ofbkx2a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/or4ltyi1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36021', 'data', 'file=/tmp/tmpajsmnivi/7ofbkx2a.json', 'init=/tmp/tmpajsmnivi/or4ltyi1.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeldmpo85b3/prophet_model-20250505094808.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 5.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7o0naemw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/gcrsjkoz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65441', 'data', 'file=/tmp/tmpajsmnivi/7o0naemw.json', 'init=/tmp/tmpajsmnivi/gcrsjkoz.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelzrrfzpwy/prophet_model-20250505094808.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/jk0rmuki.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/aseoolyy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97298', 'data', 'file=/tmp/tmpajsmnivi/jk0rmuki.json', 'init=/tmp/tmpajsmnivi/aseoolyy.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model0lrrf7kh/prophet_model-20250505094809.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:48:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/b10cq0e4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/k8qbqjfe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22189', 'data', 'file=/tmp/tmpajsmnivi/b10cq0e4.json', 'init=/tmp/tmpajsmnivi/k8qbqjfe.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modely868p91h/prophet_model-20250505094809.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:48:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:48:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/r8lh_g00.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/mkmwidvx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44323', 'data', 'file=/tmp/tmpajsmnivi/r8lh_g00.json', 'init=/tmp/tmpajsmnivi/mkmwidvx.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeltjzlgx65/prophet_model-20250505094810.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# ...
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12867', 'data', 'file=/tmp/tmpajsmnivi/gvsitfnz.json', 'init=/tmp/tmpajsmnivi/fos6rl7k.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model40vsnqkt/prophet_model-20250505094953.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 12.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/lg4w6hcq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/rf7ihcjr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76372', 'data', 'file=/tmp/tmpajsmnivi/lg4w6hcq.json', 'init=/tmp/tmpajsmnivi/rf7ihcjr.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeli_kiajgq/prophet_model-20250505094953.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/lfgwt8xr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ggesoenz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17984', 'data', 'file=/tmp/tmpajsmnivi/lfgwt8xr.json', 'init=/tmp/tmpajsmnivi/ggesoenz.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelu402jlyf/prophet_model-20250505094953.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/5an_reg_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/3qm2wv2o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24296', 'data', 'file=/tmp/tmpajsmnivi/5an_reg_.json', 'init=/tmp/tmpajsmnivi/3qm2wv2o.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modeleiu8dzvn/prophet_model-20250505094953.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/bppw6m3p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/j3add11i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18372', 'data', 'file=/tmp/tmpajsmnivi/bppw6m3p.json', 'init=/tmp/tmpajsmnivi/j3add11i.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelpc8gjucr/prophet_model-20250505094954.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/6d3rg8qm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/w7xmgf2b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86967', 'data', 'file=/tmp/tmpajsmnivi/6d3rg8qm.json', 'init=/tmp/tmpajsmnivi/w7xmgf2b.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelnwojfgli/prophet_model-20250505094954.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/8adkhd5h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/wb77mz6j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31556', 'data', 'file=/tmp/tmpajsmnivi/8adkhd5h.json', 'init=/tmp/tmpajsmnivi/wb77mz6j.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelpluw5x4s/prophet_model-20250505094954.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/21wixnjw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/cxj4wry7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47928', 'data', 'file=/tmp/tmpajsmnivi/21wixnjw.json', 'init=/tmp/tmpajsmnivi/cxj4wry7.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model475h41ix/prophet_model-20250505094954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/5tsmkubn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/o_rrrx8g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64459', 'data', 'file=/tmp/tmpajsmnivi/5tsmkubn.json', 'init=/tmp/tmpajsmnivi/o_rrrx8g.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model5xe46lb5/prophet_model-20250505094954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/v5ues_bm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/7j0ky4ct.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34946', 'data', 'file=/tmp/tmpajsmnivi/v5ues_bm.json', 'init=/tmp/tmpajsmnivi/7j0ky4ct.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model864_vv0p/prophet_model-20250505094954.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/6uhpbvmu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/wz7z0vm6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93064', 'data', 'file=/tmp/tmpajsmnivi/6uhpbvmu.json', 'init=/tmp/tmpajsmnivi/wz7z0vm6.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelo69h41n2/prophet_model-20250505094955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 17.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/ltbehckg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/c92yio6e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39386', 'data', 'file=/tmp/tmpajsmnivi/ltbehckg.json', 'init=/tmp/tmpajsmnivi/c92yio6e.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model24gjebxb/prophet_model-20250505094955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 7.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/66h3dnk4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/9xu28bic.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15452', 'data', 'file=/tmp/tmpajsmnivi/66h3dnk4.json', 'init=/tmp/tmpajsmnivi/9xu28bic.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelzwmtajpn/prophet_model-20250505094955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/6sq5onme.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/doi36f_1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38108', 'data', 'file=/tmp/tmpajsmnivi/6sq5onme.json', 'init=/tmp/tmpajsmnivi/doi36f_1.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model8oeg5ag_/prophet_model-20250505094955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:49:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/jh52gl9r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/74vkz03f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88750', 'data', 'file=/tmp/tmpajsmnivi/jh52gl9r.json', 'init=/tmp/tmpajsmnivi/74vkz03f.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model_2fl0xmq/prophet_model-20250505094955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/xl4qfshu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/q7978nov.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17219', 'data', 'file=/tmp/tmpajsmnivi/xl4qfshu.json', 'init=/tmp/tmpajsmnivi/q7978nov.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_model0nn52ei6/prophet_model-20250505094955.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/nx8ohyqt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/z4rcd6it.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36293', 'data', 'file=/tmp/tmpajsmnivi/nx8ohyqt.json', 'init=/tmp/tmpajsmnivi/z4rcd6it.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelaikqz06r/prophet_model-20250505094956.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/bhkdq6zv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/9euzfo9j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50329', 'data', 'file=/tmp/tmpajsmnivi/bhkdq6zv.json', 'init=/tmp/tmpajsmnivi/9euzfo9j.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelbq1hl0u_/prophet_model-20250505094956.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/mn3ggrb1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpajsmnivi/nly0g2hj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10309', 'data', 'file=/tmp/tmpajsmnivi/mn3ggrb1.json', 'init=/tmp/tmpajsmnivi/nly0g2hj.json', 'output', 'file=/tmp/tmpajsmnivi/prophet_modelkyrjl0xn/prophet_model-20250505094956.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 09:49:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:49:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# === REGRESSOR METRICS ===
# -- Spend -- MAE: 33056.48375879503 RMSE: 93532.5650345117 R2: 0.13161612630881137
# -- Qty   -- MAE: 2.3263789571514644 RMSE: 6.8436803690160115 R2: 0.0982567228440826
#    Customer_Phone  SKU_Code last_purchase_date pred_next_date    pred_spend  \
# 0      7010009941  10002849         2024-10-03     2024-11-21  27030.351562
# 1      7010009941  10002866         2024-12-26     2025-03-20  23784.468750
# 2      7010009941  10002857         2025-01-02     2025-04-03  23784.468750
# 3      7010147753  10002849         2024-10-16     2024-11-20  26422.642578
# 4      7010147753  10002832         2024-10-03     2024-11-09  34583.308594
# 5      7010147753  10002866         2024-09-11     2024-09-11  25418.720703
# 6      7010301833  10002832         2024-10-22     2024-12-01  76847.632812
# 7      7010301833  10002830         2024-10-22     2024-10-22  30868.351562
# 8      7010301833  10003376         2025-01-06     2024-12-24  52129.347656
# 9      7010572000  10000539         2024-10-23     2024-10-23  86765.750000
#
#    pred_qty  probability
# 0  1.361134     0.786555
# 1  1.203211     0.462454
# 2  1.180941     0.407207
# 3  1.321600     0.823764
# 4  1.710547     0.770259
# 5  1.346955     0.538113
# 6  5.201844     0.555498
# 7  1.604616     0.491128
# 8  2.648791     0.485204
# 9  6.205529     0.711128

# %%
# Save the final predictions to CSV
results[['Customer_Phone','SKU_Code','last_purchase_date',
         'pred_next_date','pred_spend','pred_qty','probability']] \
    .to_csv('sku_predictions.csv', index=False)
